# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

import pandas as pd
import numpy as np

import datetime
import os

# %matplotlib inline

from graphics_utils.plot_utils import *
def tensor_str_to_float(x):
    try:
        return float(x[9:15])
    except Exception as e:
        print(e)
        return np.nan
def unlist(x):
    return float(x.replace('[','').replace(']',''))

from PIL import Image

# %%
verbose = 0

# %%
def get_mean_interpolated_stats_df_wrapper(log_path, **kwargs):
    new_x, new_y, runs, interp_funcs = get_mean_interpolated_stats_df(log_path, **kwargs)
    return new_x, new_y, runs

# %%
def draw_meanIntep_with_colored_runs_wrapper(new_x, new_y, runs, **kwargs):
    ax = draw_meanIntep_with_colored_runs(
        new_y, runs, new_x, **kwargs
    )
    return ax

# %%
def draw_mean_with_std_wrapper(new_x, new_y, runs, **kwargs):
    ax = draw_mean_with_std(new_y, runs, new_x, **kwargs)
    return ax

# %%
name9 = "1024fc_A3CRules2378MemOracleFC_32w_g099_noRMS_gOracle00"
noent9 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name9}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent9,
    label=name9, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name10 = "1024fc_A3CRules2378MemOracle_32w_g099_noRMS_gOracle00"
noent10 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name10}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent10, label=name10, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  251

# %%
name11 = "1024fc_A3CRules2378MemOracle_32w_g099_noRMS_gOracle09"
noent11 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name11}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent11, label=name11, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  267

# %%
name12 = "1024fc_A3CRules2378MemOracleFC_32w_g099_noRMS_gOracle09"
noent12 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name12}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent12, label=name12, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  267

# %%
name13 = "1024fc_A3CRules2378MemOracle_32w_g099_noRMS_gOracle09_reward"
noent13 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name13}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent13, 
    label=name13, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  298

# %%
name14 = '1024fc_A3CRules2378MemOracle_32w_g099_noRMS_gOracle00_reward'

noent14 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name14}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent14, label=name14, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name15 = '1024fc_A3CRules2378OracleIntrinsicCritic_32w_g099_noRMS_gOracle09_gIntrinsics099'
noent15 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name15}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent15, label=name15, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name16 = '1024fc_A3CRules2378OracleIntrinsicCritic_32w_g099_noRMS_gOracle00_gIntrinsics099'
noent16 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name16}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent16, label=name16, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  256

# %%
name17 = '1024fc_A3CRules2378OracleIntrinsicCritic_32w_8_64'
noent17 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name17}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent17, label=name17, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  235

# %% [raw]
# name17 = '1024fc_A3CRules2378OracleIntrinsicCritic_32w_8_64_v2'
# noent17 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name17}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)
#
# ax = draw_meanIntep_with_colored_runs_wrapper(
#     *noent17, label=name17, colormap="rainbow", alpha=0.8)
#
# ax.tick_params(axis='both', which='major', labelsize=10)
# ax.tick_params(axis='both', which='minor', labelsize=8)
#
#
# plt.xlabel('Общее число кадров', fontsize=18)
# plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)
#
# plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
#           fancybox=True, shadow=True, prop={'size': 15})

# %%
name18 = '1024fc_A3CRules2378OracleIntrinsicCritic_32w_8_64_v3'
noent18 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name18}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent18, label=name18, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name19 = '1024fc_A3CRules2378OracleSplitEncoders_32w_8_64_v2'
noent19 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name19}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent19, label=name19, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  383

# %%
name20 = '1024fc_A3CRules2378OracleSplitEncodersIntrinsicCritic_32w_8_64_v2'
noent20 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name20}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent20, label=name20, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  298

# %%
name21 = '1024fc_A3CRules2378Oracle_32w_8_64_v3'
noent21 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name21}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent21, label=name21, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  297

# %%
name22 = '1024fc_A3CRules2378Oracle_32w_8_64_v3_relu_g_false'
noent22 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name22}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent22, label=name22, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name23 = '1024fc_A3CRules2378OracleSplitEncodersSharedDiff_32w_8_64_v2'
noent23 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name23}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent23, label=name23, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  490

# %%
name24 = '1024fc_A3CRules2378OracleSplitEncoders_noOracle_32w_8_64_v2'
noent24 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name24}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent24, label=name24, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  426

# %%
name25 = '1024fc_A3CRules2378OracleSplitEncodersSharedDiffBoth_noOracle_32w_8_64_v2'
noent25 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name25}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent25, label=name25, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  551

# %%
name26 = '1024fc_A3CRules2378OracleSplitEncodersSharedDiffConcatBoth_noOracle_32w_8_64_v2'
noent26 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name26}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent26, label=name26, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  522

# %%
name27 = '1024fc_A3CRules2378OracleNoSplitSharedDiffConcatBoth_noOracle_32w_8_64_v2'
noent27 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name27}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent27, label=name27, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name28 = '1024fc_A3CRules2378OracleNoSplitSharedDiffConcatBoth_noOracle_noDetach_32w_8_64_v2'
noent28 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name28}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent28, label=name28, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name29 = '1024fc_A3CRules2378OracleSplitEncodersSharedDiffConcatMemdiffBoth_noOracle_32w_8_64_v2'
noent29 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name29}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent29, label=name29, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name30 = '1024fc_A3CRules2378OracleSplitEncodersSharedDiffConcatMemdiffBoth_32w_8_64_v2'
noent30 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name30}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent30, label=name30, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# num of logs in folder  266

# %%
name31 = '1024fc_A3CRules2378OracleNoSplitSharedDiffConcatMemdiffBoth_noOracle_32w_8_64_v2'
noent31 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name31}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent31, label=name31, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})

# %%
name32 = '1024fc_A3CRules2378OracleNoSplitSharedDiffConcatMemdiffRawBoth_noOracle_32w_8_64_v2'
noent32 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name32}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent32, label=name32, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})

# %%
name33 = '1024fc_A3CRules2378OracleNoSplitSharedDiffConcatMemdiffRawBoth_noOracle_32w_8_64_v2_advantage'
noent33 = get_mean_interpolated_stats_df_wrapper(f"./logs/{name33}/", verbose=verbose, min_frames_in_log_to_use_it=2000000)#900000)

ax = draw_meanIntep_with_colored_runs_wrapper(
    *noent33, label=name33, colormap="rainbow", alpha=0.8)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})

# %%
ax = draw_mean_with_std_wrapper(*noent9, label=name9, col="yellow", alpha=0.5)
# draw_mean_with_std_wrapper(*noent10, ax = ax, label=name10, col="brown", alpha=0.5)
# draw_mean_with_std_wrapper(*noent11, ax = ax, label=name11, col="green", alpha=0.5)
# draw_mean_with_std_wrapper(*noent12, ax = ax, label=name12, col="blue", alpha=0.5)
# draw_mean_with_std_wrapper(*noent13, ax = ax, label=name13, col="red", alpha=0.5)
# draw_mean_with_std_wrapper(*noent14, ax = ax, label=name14, col="cyan", alpha=0.5)
# draw_mean_with_std_wrapper(*noent15, ax = ax, label=name15, col="magenta", alpha=0.5)
# draw_mean_with_std_wrapper(*noent16, ax = ax, label=name16, col="black", alpha=0.5)
# draw_mean_with_std_wrapper(*noent17, ax = ax, label=name17, col="orange", alpha=0.5)
draw_mean_with_std_wrapper(*noent18, ax = ax, label=name18, col="green", alpha=0.5)
draw_mean_with_std_wrapper(*noent19, ax = ax, label=name19, col="cyan", alpha=0.5)
draw_mean_with_std_wrapper(*noent20, ax = ax, label=name20, col="red", alpha=0.5)
draw_mean_with_std_wrapper(*noent21, ax = ax, label=name21, col="blue", alpha=0.5)
draw_mean_with_std_wrapper(*noent22, ax = ax, label=name22, col="pink", alpha=0.5)
draw_mean_with_std_wrapper(*noent23, ax = ax, label=name23, col="coral", alpha=0.5)
draw_mean_with_std_wrapper(*noent24, ax = ax, label=name24, col="black", alpha=0.5)
draw_mean_with_std_wrapper(*noent25, ax = ax, label=name25, col="purple", alpha=0.5)
draw_mean_with_std_wrapper(*noent26, ax = ax, label=name26, col="orange", alpha=0.5)
draw_mean_with_std_wrapper(*noent27, ax = ax, label=name27, col="magenta", alpha=0.5)
draw_mean_with_std_wrapper(*noent28, ax = ax, label=name28, col="olive", alpha=0.5)
draw_mean_with_std_wrapper(*noent29, ax = ax, label=name29, col="darkgoldenrod", alpha=0.5)
draw_mean_with_std_wrapper(*noent30, ax = ax, label=name30, col="slategray", alpha=0.5)
draw_mean_with_std_wrapper(*noent31, ax = ax, label=name31, col="teal", alpha=0.5)
draw_mean_with_std_wrapper(*noent32, ax = ax, label=name32, col="limegreen", alpha=0.5)
draw_mean_with_std_wrapper(*noent33, ax = ax, label=name33, col="darkgreen", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})

# %%
name34 = 'edc_nosplit_concat_both_no_oracle_8_64_v2_advantage'
noent34 = get_mean_interpolated_stats_df_wrapper(f'./logs/{name34}/', verbose=verbose, min_frames_in_log_to_use_it=2000000)
fig, ax = plt.subplots(figsize=(12, 8))
draw_meanIntep_with_colored_runs_wrapper(*noent34, label='EDC: advantage, no memory/oracle, post-conv delta', colormap='rainbow', alpha=.8)
plt.xlabel('Frames')
plt.ylabel('Mean reward')
plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})

# %%
name34 = 'edc_nosplit_concat_both_no_oracle_8_64_v2_advantage'
name35 = 'control_nosplit_concat_both_no_oracle_8_64_v2_advantage'

noent34 = get_mean_interpolated_stats_df_wrapper(f'./logs/{name34}/', verbose=verbose, min_frames_in_log_to_use_it=2000000)
noent35 = get_mean_interpolated_stats_df_wrapper(f'./logs/{name35}/', verbose=verbose, min_frames_in_log_to_use_it=2000000)

ax = draw_mean_with_std_wrapper(*noent34, label='EDC on', col='blue', alpha=.3)
draw_mean_with_std_wrapper(*noent35, ax=ax, label='EDC off', col='orange', alpha=.3)
plt.xlabel('Frames')
plt.ylabel('Mean reward')
plt.legend()
