# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

import pandas as pd
import numpy as np

import datetime
import os

# %matplotlib inline

from graphics_utils.plot_utils import *
def tensor_str_to_float(x):
    try:
        return float(x[9:15])
    except Exception as e:
        print(e)
        return np.nan
def unlist(x):
    return float(x.replace('[','').replace(']',''))

from PIL import Image

# %%
#!pip install pandas

# %%
# get_log_df("./logs/BaseFirstTest_0/PongNoFrameskip-v4_log")

# %%
new_x, new_y, runs, interp_funcs = get_mean_interpolated_stats_df("./logs/BaseFirstTest_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# Out:
# num of logs in folder  1

# %%
draw_mean_with_std(new_y,runs,new_x)
# Out:
# <AxesSubplot:xlabel='frames_total', ylabel='mean_reward_10'>

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy", col="red")

plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="upper left", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent16, new_y_noent16, runs_noent16, interp_funcs_noent16 = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_16w_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_8w_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_4w_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent16,runs_noent16,new_x_noent16, ax = ax, label="base_no_entropy16", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="base_no_entropy8", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="base_no_entropy4", col="magenta", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("/home/users/aamore/rl_a3c_pytorch/logs/BaseNoEntropy_32w_g095/", verbose=2, min_frames_in_log_to_use_it=1)#900000)

# %%
get_log_df("./logs/BaseNoEntropy_32w_g095/PongNoFrameskip-v4_log_1")

# %%
kek, kes = get_mean_stats_df("./logs/BaseNoEntropy_32w_g095/")

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_32w_g095/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_32w_g09/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="base_no_entropy_g095", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="base_no_entropy_g09", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_32w_g09/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="1024fc_1frame_input_32w", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="base_no_entropy_g09", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat_1024fc/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_meanIntep_and_runs(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_meanIntep_and_runs(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_meanIntep_and_runs(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcat_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat_1024fc/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcat_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcatNoNorm_1024fc/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcatNoNorm_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcatNoNormNormedNeighbours_1024fc/", verbose=0, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcatNoNormNormedNeighbours_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcatNoNormAtAll_1024fc/", verbose=2, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent,runs_noent,new_x_noent, ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcatNoNormAtAll_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcatNoNormAtAll_1024fc/", verbose=2, min_frames_in_log_to_use_it=3)#900000)

ax = draw_mean_with_std(new_y, runs, new_x,  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end=500
draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2,runs_noent2,new_x_noent2, ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcatNoNormAtAll_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInput_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat1frameNormBoth_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=100

ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end],[i[:end] for i in runs_noent2],new_x_noent2[:end], ax = ax, label="Our_32w_g099_diffInput_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_diffInputConcat1frameNormBoth", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat1frameNormBoth_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=100

ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2 = 600
draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="Our_32w_g099_diffInputConcat1frameNormBoth_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat1frameNormBoth_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXNormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=100

ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="base", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200
draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], ax = ax, label="base_no_entropy32", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="Our_32w_g099_diffInputConcat1frameNormBoth_1024fc", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_Concat1frameNormXNormDiffOnNormed_1024fc", col="green", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frameNorm1frame/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat1frameNormBoth_1024fc_DiffFromNoNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="LSTM_no_entropy_RunGameNorm_a09999_g099_32w", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_1frameNorm_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frameNormDiffOnNotNormed_1frameNorm_g099_32w", col="magenta", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/BaseNoEntropy_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha09/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_diffInputConcat1frameNormBoth_1024fc_DiffFromNoNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="LSTM_no_entropy_RunGameNorm_a09999_g099_32w", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frameNormDiffOnNotNormed_1frameNorm_g099_32w", col="magenta", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/LSTM_no_entropy_RunGameNorm_a09999_g099_32w/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha09/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200#draw_mean_with_std
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="LSTM_no_entropy_RunGameNorm_a09999_g099_32w", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/LSTM_no_entropy_RunGameNorm_a09999_g099_32w/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha09/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200#draw_mean_with_std
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="LSTM_no_entropy_RunGameNorm_a09999_g099_32w", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099_memv1/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha09/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200#draw_mean_with_std
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_1frame_RunGameNorm_a099_32w_g099_MEM", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_1frameDiff_LayerNorm_32w_g099_3/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/Our_1frameDiff_LayerNormSX_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha09/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200#draw_mean_with_std
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_1frameNoNormDiffOnNoNorm_LayerNormX_32w_g099/", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end],ax=ax, label="1024fc_1frameNoNormDiffOnNoNorm_LayerNormXS_32w_g099/", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_SNormStdMean_1024fc_2/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_SNormStdMean_1024fc/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha09/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)

end2=1200#draw_mean_with_std draw_meanIntep_and_runs
ax = draw_meanIntep_and_runs(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_SNormStdMean_32w_g099/", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end],ax=ax, label="forme", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)



plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_normS_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_NoLastConvRelu_LN1stChannel_DiffonNotNormed_32w_g099//", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end],ax=ax, label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_normS_32w_g099", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_1frame_RunGameNorm_a09_g099_32w", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_normS_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end],ax=ax, label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_normS_32w_g099", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end],ax=ax, label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_VAE008kld01rest_32w_g099", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKL_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvKL_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="tst", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKL_NormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="tst", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_1frame_GameRunningNorm/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_1frame_RunGameNorm_a09999_g099_32w", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKL_NormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="wrong /1024 init and kl", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConv4NormalizeChannelsFanInFanOutNoKL_NormSLenNoDetachFanInEncoderOutNmChannels_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConv4NormalizeChannelsFanInFanOutNoKL_NormSLenNoDetachFanInEncoderOutNmChannels_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConv4NormalizeChannelsFanInFanOutNoKL_NormSLenNoDetachFanInEncoderOutNmChannels_DiffConcat1frameNoNormDiffFromNormed_32w_g099_hpc5/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConv4NormalizeChannelsFanInFanOutNoKL_NormSLenNoDetachFanInEncoderOutNmChannels_DiffConcat1frameNoNormDiffFromNormed_32w_g099_hpc5", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalize_DiffConcat1frameNoNormDiffFromNormed_32w_g099_hpc5/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalize_DiffConcat1frameNoNormDiffFromNormed_32w_g099_hpc5", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="no detach norm", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTDetachNorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvWithFanOut1ForLastConvNoKL_NormSLen4detachZnam_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTDetachNorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTDetachNorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix//", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentio", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTDetachNorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="detached denominator", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_1frameNorm_g099_32w", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderLayernorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs///", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_origNorm_alpha099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderLayernorm_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_1frame_RunGameNorm_a099_g099_32w", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp//", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs///", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs///", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs///", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="red", alpha=0.5)
draw_meanIntep_and_runs(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs///", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="red", alpha=0.5)
draw_meanIntep_and_runs(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099_2fix_10runs///", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcConvKLNormSLen_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs_fix/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxTNODetach_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="red", alpha=0.5)
draw_meanIntep_and_runs(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_EncoderConvKLNormSLenCentered_DiffConcat1frameNoNormDiffFromNormed_32w_g099_10runs", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderGramSchmidt_OrthonormalSqrt3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a09/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
### new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderGramSchmidt_OrthonormalSqrt3_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a09_g099_32w", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderGramSchmidt_OrthonormalSqrt3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrthoNormConv4_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_ConcatGameNormNoNormDiffOnNorm_1024fc_a099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
### new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderGramSchmidt_OrthonormalSqrt3_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3C1024fcGSOrthoNormConv4_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_1frameNoNormDiffOnNormed_RunGameNorm_a099_g099_32w", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderGramSchmidt_OrthonormalSqrt3_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrthoNormConv4_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrthoNormConv4NoRelu_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
### new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_EncoderConvAttentionAfterLastPoolCNormalizeCenterOrder_DiffConcat1frameNoNormDiffFromNormed_32w_g099_ndTemp", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderGramSchmidt_OrthonormalSqrt3_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3C1024fcGSOrthoNormConv4_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3C1024fcGSOrthoNormConv4NoRelu_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrthoNormConv4_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcGSOrthoNormConv4NoRelu_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
### new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_1024fc/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3C1024fcGSOrtho_DiffConcat1frameNoNormDiffFromNormed_32w_g099", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3C1024fcGSOrthoNormConv4_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3C1024fcGSOrthoNormConv4NoRelu_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="cyan", alpha=0.5)

ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)

end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_", col="cyan", alpha=0.5)
draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_fixinit", col="olive", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_", col="cyan", alpha=0.5)
# draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_fixinit", col="olive", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="cyan", alpha=0.5)
draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="olive", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, ax = ax, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="cyan", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="olive", alpha=0.5)
draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="silver", alpha=0.5)
draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="brown", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower right", prop={'size': 15})

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="cyan", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="olive", alpha=0.5)
draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules2345678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="brown", alpha=0.5)
draw_mean_with_std(new_y_noent11,runs_noent11,new_x_noent11, ax = ax, label="1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="brown", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# verbose  2
# num of logs in folder  199
# log_len  417
# log_len  412
# log_len  415
# log_len  399
# log_len  393
# log_len  388
# log_len  284
# Minimal log len 284
# So final min_len is 245
# Got log df len  379
# Got last framenum  14976113
# Got first framenum  6318
# Got log df len  374
# Got last framenum  14986736
# Got first framenum  6359
# Got log df len  377
# Got last framenum  14976483
# Got first framenum  6655
# Got log df len  361
# Got last framenum  14988067
# Got first framenum  6539
# Got log df len  355
# Got last framenum  14987936
# Got first framenum  6759
# Got log df len  350
# Got last framenum  14968388
# Got first framenum  7214
# Got log df len  246
# Got last framenum  14949950
# Got first framenum  6639
# X from  6318  to  14949950
# verbose  2
# num of logs in folder  527
# log_len  453
# log_len  477
# log_len  776
# log_len  295
# log_len  339
# log_len  707
# log_len  745
# log_len  431
# log_len  378
# log_len  450
# log_len  499
# log_len  775
# ...

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378GS_NoNormNoSoftmax_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="cyan", alpha=0.5)
draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules2378GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="magenta", alpha=0.5)
draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="yellow", alpha=0.5)
draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN", col="brown", alpha=0.5)
draw_mean_with_std(new_y_noent11,runs_noent11,new_x_noent11, ax = ax, label="1024fc_A3CRules2378GS_NoNormNoSoftmax_32w_g099", col="green", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# verbose  2
# num of logs in folder  199
# log_len  417
# log_len  412
# log_len  415
# log_len  399
# log_len  393
# log_len  388
# log_len  284
# Minimal log len 284
# So final min_len is 245
# Got log df len  379
# Got last framenum  14976113
# Got first framenum  6318
# Got log df len  374
# Got last framenum  14986736
# Got first framenum  6359
# Got log df len  377
# Got last framenum  14976483
# Got first framenum  6655
# Got log df len  361
# Got last framenum  14988067
# Got first framenum  6539
# Got log df len  355
# Got last framenum  14987936
# Got first framenum  6759
# Got log df len  350
# Got last framenum  14968388
# Got first framenum  7214
# Got log df len  246
# Got last framenum  14949950
# Got first framenum  6639
# X from  6318  to  14949950
# verbose  2
# num of logs in folder  271
# log_len  400
# log_len  526
# log_len  341
# log_len  504
# log_len  427
# log_len  475
# log_len  564
# log_len  456
# log_len  558
# log_len  526
# log_len  553
# log_len  539
# ...

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="cyan", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="olive", alpha=0.5)
# draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="yellow", alpha=0.5)
draw_meanIntep_and_runs(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="yellow", alpha=0.8)

# draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN", col="brown", alpha=0.5)
# draw_mean_with_std(new_y_noent11,runs_noent11,new_x_noent11, ax = ax, label="1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="brown", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# verbose  2
# num of logs in folder  199
# log_len  417
# log_len  412
# log_len  415
# log_len  399
# log_len  393
# log_len  388
# log_len  284
# Minimal log len 284
# So final min_len is 245
# Got log df len  379
# Got last framenum  14976113
# Got first framenum  6318
# Got log df len  374
# Got last framenum  14986736
# Got first framenum  6359
# Got log df len  377
# Got last framenum  14976483
# Got first framenum  6655
# Got log df len  361
# Got last framenum  14988067
# Got first framenum  6539
# Got log df len  355
# Got last framenum  14987936
# Got first framenum  6759
# Got log df len  350
# Got last framenum  14968388
# Got first framenum  7214
# Got log df len  246
# Got last framenum  14949950
# Got first framenum  6639
# X from  6318  to  14949950
# verbose  2
# num of logs in folder  527
# log_len  353
# log_len  336
# log_len  402
# log_len  471
# log_len  431
# log_len  435
# log_len  347
# log_len  737
# log_len  404
# log_len  469
# log_len  463
# log_len  430
# ...

# %%
from graphics_utils.plot_utils import draw_meanIntep_with_colored_runs

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378GS_NoNormNoSoftmax_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="white", alpha=0.0)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="cyan", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="olive", alpha=0.5)
# draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="yellow", alpha=0.5)
ax = draw_meanIntep_with_colored_runs(new_y_noent9,runs_noent9,new_x_noent9, label="1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS", colormap="rainbow", alpha=0.8)

# draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN", col="brown", alpha=0.5)
# draw_mean_with_std(new_y_noent11,runs_noent11,new_x_noent11, ax = ax, label="1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="brown", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# verbose  2
# num of logs in folder  271
# log_len  400
# log_len  526
# log_len  341
# log_len  504
# log_len  427
# log_len  475
# log_len  564
# log_len  456
# log_len  558
# log_len  526
# log_len  553
# log_len  539
# log_len  568
# log_len  390
# log_len  466
# Minimal log len 341
# So final min_len is 302
# Got log df len  362
# Got last framenum  14993508
# Got first framenum  5635
# Got log df len  488
# Got last framenum  14994592
# Got first framenum  5896
# Got log df len  303
# Got last framenum  14955538
# Got first framenum  6015
# Got log df len  466
# Got last framenum  14990338
# Got first framenum  5878
# Got log df len  389
# Got last framenum  14984574
# Got first framenum  6179
# Got log df len  437
# Got last framenum  14975207
# Got first framenum  5640
# Got log df len  526
# Got last framenum  14994677
# Got first framenum  5915
# Got log df len  418
# Got last framenum  14991085
# Got first framenum  5959
# Got log df len  520
# Got last framenum  14980965
# ...

# %%
1024fc_A3CRules2378Mem_32w_g099_noRMS

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378Mem_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378GS_NoNormNoSoftmax_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="white", alpha=0.0)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="cyan", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_torchRMSDetach", col="olive", alpha=0.5)
# draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="yellow", alpha=0.5)
ax = draw_meanIntep_with_colored_runs(new_y_noent9,runs_noent9,new_x_noent9, label="1024fc_A3CRules2378Mem_32w_g099_noRMS", colormap="rainbow", alpha=0.8)

# draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN", col="brown", alpha=0.5)
# draw_mean_with_std(new_y_noent11,runs_noent11,new_x_noent11, ax = ax, label="1024fc_A3CRules2345678GS_GameNormNoNormDiffOnNorm_32w_g099_torchRMS", col="brown", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# verbose  2
# num of logs in folder  463
# log_len  392
# log_len  463
# log_len  502
# log_len  451
# log_len  432
# log_len  402
# log_len  664
# log_len  390
# log_len  386
# log_len  451
# log_len  410
# log_len  401
# log_len  440
# log_len  451
# log_len  412
# Minimal log len 386
# So final min_len is 347
# Got log df len  354
# Got last framenum  14972853
# Got first framenum  6761
# Got log df len  425
# Got last framenum  14976957
# Got first framenum  6135
# Got log df len  464
# Got last framenum  14987321
# Got first framenum  5995
# Got log df len  413
# Got last framenum  14974361
# Got first framenum  28080
# Got log df len  394
# Got last framenum  14996160
# Got first framenum  5938
# Got log df len  364
# Got last framenum  14980142
# Got first framenum  6282
# Got log df len  626
# Got last framenum  14993423
# Got first framenum  6156
# Got log df len  352
# Got last framenum  14980800
# Got first framenum  7121
# Got log df len  348
# Got last framenum  14973020
# ...

# %%
# new_x_noent, new_y_noent, runs_noent, interp_funcs_noent = get_mean_interpolated_stats_df("./logs/Our_32w_g099_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_1024fc_same_re2/", verbose=0, min_frames_in_log_to_use_it=200000)#900000)
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
#1024fc_EncoderConvKL_FcTanh_DiffConcat1frameNoNormDiffFromNormed_32w_g099
#Our_32w_g099_ConvAttentionKL_ConcatXDiffOnUnNormed1frameNormTogether_noReluLastConv_1024fc
# new_x_noent1, new_y_noent1, runs_noent1, interp_funcs_noent1 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# new_x_noent2, new_y_noent2, runs_noent2, interp_funcs_noent2 = get_mean_interpolated_stats_df("./logs/1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcat1frameNoNormDiffFromNormed_32w_g099/", verbose=0, min_frames_in_log_to_use_it=1)#900000)
# -----------------------------------------------------------------------------------------------------1024fc_EncoderConvAttentionAfterLastPoolCNormalizeChannelNormOrderSmaxT_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# new_x_noent3, new_y_noent3, runs_noent3, interp_funcs_noent3 = get_mean_interpolated_stats_df("./logs/1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099//", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent4, new_y_noent4, runs_noent4, interp_funcs_noent4 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent5, new_y_noent5, runs_noent5, interp_funcs_noent5 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent6, new_y_noent6, runs_noent6, interp_funcs_noent6 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent7, new_y_noent7, runs_noent7, interp_funcs_noent7 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent8, new_y_noent8, runs_noent8, interp_funcs_noent8 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent9, new_y_noent9, runs_noent9, interp_funcs_noent9 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
# new_x_noent10, new_y_noent10, runs_noent10, interp_funcs_noent10 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)
new_x_noent11, new_y_noent11, runs_noent11, interp_funcs_noent11 = get_mean_interpolated_stats_df("./logs/1024fc_A3CRules2378Mem_32w_g099_noRMS/", verbose=2, min_frames_in_log_to_use_it=2000000)#900000)


end=200

# ax = draw_mean_with_std(new_y[:end], [i[:end] for i in runs], new_x[:end],  col="black", label="LSTM_with_entropy", alpha=0)


end2=1200#draw_mean_with_std #VAE_WithDecoder_DiffConcat1frameNoNormDiffFromNormed_32w_g099
# ax = draw_mean_with_std(new_y_noent[:end],[i[:end] for i in runs_noent],new_x_noent[:end], label="1024fc_Concat1frameNormXUnnormDiffOnNormed_noReluLastConv_32w_g099", col="red", alpha=0.5)
# ax = draw_mean_with_std(new_y_noent1[:end],[i[:end] for i in runs_noent1],new_x_noent1[:end], label="1024fc_A3C1024fc_DiffConcat1frameNoNormDiffFromNormed_32w_g099_15runs", col="green", alpha=0.5)
# draw_mean_with_std(new_y_noent2[:end2],[i[:end2] for i in runs_noent2],new_x_noent2[:end2], ax = ax, label="1024fc_EncoderConvDefaultInitAbsMaxPoolSignPreserve_DiffConcatGameNormNoNormDiffFromNormed_32w_g099(12378)", col="blue", alpha=0.5)
# draw_mean_with_std(new_y_noent3,runs_noent3,new_x_noent3, ax = ax, label="1024fc_A3C1024fcOurInitForGameNorm_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
ax = draw_mean_with_std(new_y_noent4,runs_noent4,new_x_noent4, label="1024fc_A3CRules2378_GameNormNoNormDiffOnNorm_32w_g099_fixinit/", col="black", alpha=0.5)
# draw_mean_with_std(new_y_noent5,runs_noent5,new_x_noent5, ax = ax, label="1024fc_A3CRules23478_GameNormNoNormDiffOnNorm_32w_g099_fixRMSmy", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules2345678_GameNormNoNormDiffOnNorm_32w_g099_/", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent6,runs_noent6,new_x_noent6, ax = ax, label="1024fc_A3CRules235678GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="cyan", alpha=0.5)
# draw_mean_with_std(new_y_noent7,runs_noent7,new_x_noent7, ax = ax, label="1024fc_A3CRules2378GSChangeOrder_GameNormNoNormDiffOnNorm_32w_g099", col="red", alpha=0.5)
# draw_mean_with_std(new_y_noent8,runs_noent8,new_x_noent8, ax = ax, label="1024fc_A3CRules235678GS_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="magenta", alpha=0.5)
# draw_mean_with_std(new_y_noent9,runs_noent9,new_x_noent9, ax = ax, label="1024fc_A3CRules235678_GameNormNoNormDiffOnNorm_32w_g099_noRMS", col="yellow", alpha=0.5)
# draw_mean_with_std(new_y_noent10,runs_noent10,new_x_noent10, ax = ax, label="1024fc_A3CRules2345678LayerNorm_GameNormNoNormDiffOnNorm_32w_g099_torchLN", col="brown", alpha=0.5)
draw_mean_with_std(new_y_noent11,runs_noent11,new_x_noent11, ax = ax, label="1024fc_A3CRules2378Mem_32w_g099_noRMS", col="green", alpha=0.5)


ax.tick_params(axis='both', which='major', labelsize=10)
ax.tick_params(axis='both', which='minor', labelsize=8)


plt.xlabel('Общее число кадров', fontsize=18)
plt.ylabel('Средняя награда за последние 10 тестов', fontsize=18)

plt.legend(loc="lower center", bbox_to_anchor=(0.5, -0.31),
          fancybox=True, shadow=True, prop={'size': 15})
# Out:
# verbose  2
# num of logs in folder  199
# log_len  417
# log_len  412
# log_len  415
# log_len  399
# log_len  393
# log_len  388
# log_len  284
# Minimal log len 284
# So final min_len is 245
# Got log df len  379
# Got last framenum  14976113
# Got first framenum  6318
# Got log df len  374
# Got last framenum  14986736
# Got first framenum  6359
# Got log df len  377
# Got last framenum  14976483
# Got first framenum  6655
# Got log df len  361
# Got last framenum  14988067
# Got first framenum  6539
# Got log df len  355
# Got last framenum  14987936
# Got first framenum  6759
# Got log df len  350
# Got last framenum  14968388
# Got first framenum  7214
# Got log df len  246
# Got last framenum  14949950
# Got first framenum  6639
# X from  6318  to  14949950
# verbose  2
# num of logs in folder  463
# log_len  392
# log_len  463
# log_len  502
# log_len  451
# log_len  432
# log_len  402
# log_len  664
# log_len  390
# log_len  386
# log_len  451
# log_len  410
# log_len  401
# ...
