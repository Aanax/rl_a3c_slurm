# %%
import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20})

import pandas as pd
import numpy as np

import datetime
import os

# %matplotlib inline

from graphics_utils.plot_utils import *
def tensor_str_to_float(x):
    try:
        return float(x[9:15])
    except Exception as e:
        print(e)
        return np.nan
def unlist(x):
    return float(x.replace('[','').replace(']',''))

from PIL import Image

# %%
#!pip install pandas

# %%
get_log_df("./logs/BaseFirstTest_0/PongNoFrameskip-v4_log")
# Out:
# ---
# ['2025-09-27' '14:17:57261' ':' 'Time' '00h' '00m' '18s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '757' 'reward' 'mean' '-21.0000'
#  'frames_total' '5700']
# ---
# ['2025-09-27' '14:19:16440' ':' 'Time' '00h' '01m' '37s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '755' 'reward' 'mean' '-21.0000'
#  'frames_total' '33785']
# ---
# ['2025-09-27' '14:20:32460' ':' 'Time' '00h' '02m' '53s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '757' 'reward' 'mean' '-21.0000'
#  'frames_total' '60737']
#    episode_reward  episode_length  reward_mean  frames_total  \
# 0           -21.0             757        -21.0          5700
# 0           -21.0             755        -21.0         33785
# 0           -21.0             757        -21.0         60737
#
#           server_time  total_run_time  reward_mean_10
# 0 2025-09-27 14:17:57 0 days 00:00:18             NaN
# 0 2025-09-27 14:19:16 0 days 00:01:37             NaN
# ...

# %%
new_x, new_y, runs, interp_funcs = get_mean_interpolated_stats_df("./logs/BaseFirstTest_0/", verbose=0, min_frames_in_log_to_use_it=3)#900000)
# Out:
# ---
# ['2025-09-27' '14:17:57261' ':' 'Time' '00h' '00m' '18s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '757' 'reward' 'mean' '-21.0000'
#  'frames_total' '5700']
# ---
# ['2025-09-27' '14:19:16440' ':' 'Time' '00h' '01m' '37s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '755' 'reward' 'mean' '-21.0000'
#  'frames_total' '33785']
# ---
# ['2025-09-27' '14:20:32460' ':' 'Time' '00h' '02m' '53s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '757' 'reward' 'mean' '-21.0000'
#  'frames_total' '60737']
# ---
# ['2025-09-27' '14:21:49511' ':' 'Time' '00h' '04m' '10s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '762' 'reward' 'mean' '-21.0000'
#  'frames_total' '87638']
# ---
# ['2025-09-27' '14:23:06119' ':' 'Time' '00h' '05m' '27s' 'episode'
#  'reward' '-21.0' 'episode' 'length' '762' 'reward' 'mean' '-21.0000'
#  'frames_total' '114761']
# ---
# ['2025-09-27' '14:24:22596' ':' 'Time' '00h' '06m' '43s' 'episode'
# ...

# %%
draw_mean_with_std(new_y,runs,new_x)
# Out:
# <AxesSubplot:xlabel='frames_total', ylabel='mean_reward_10'>
