# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
kek = np.load("/home/aanax/Desktop/rl_a3c_slurm/Eval_2026-06-11_00:58:49_Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14/Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14_rewards.npy")

# %%
kek.shape
# Out:
# (1318,)

# %%
kek [0]
# Out:
# 0.0

# %%
np.sum(kek)
# Out:
# -21.0

# %%
len(kek)
# Out:
# 1318

# %%
plt.plot(kek)

# %%
kek2 = np.load("/home/aanax/Desktop/rl_a3c_slurm/Eval_2026-06-12_15:09:36_Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14_zeroing/Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14_rewards.npy")

# %%
len(kek2)
# Out:
# 1320

# %%
np.sum(kek2)
# Out:
# -21.0

# %%
plt.plot(kek2)

# %%
plt.figure()
plt.plot(kek)
plt.plot(kek2)
plt.show()

# %%
aas = np.load("/home/aanax/Desktop/rl_a3c_slurm/Eval_2026-06-11_00:58:49_Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14/Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14_aas.npy")
aas2 = np.load("/home/aanax/Desktop/rl_a3c_slurm/Eval_2026-06-12_15:09:36_Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14_zeroing/Hierarchial_interactor_options_betaterm_32w_g_075_g2_099_fix3_gradclip_14_aas.npy")

# %%
plt.figure()
plt.plot(aas[:100])
plt.plot(aas2[:100])
plt.show()
